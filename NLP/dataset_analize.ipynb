# %%
import pandas as pd

# %%
doc_path = 'all_recepies_inter.csv'

# %%
# Посмотерть как обучалась модель.

# %%
df = pd.read_csv(doc_path, sep='\t')

# %%
df
# Out:
#        Unnamed: 0                                               name  \
# 0               0  рассольник классический с перловкой и солеными...
# 1               1                    Суп пюре из белокочаной капусты
# 2               2                     Постные щи из квашеной капусты
# 3               3                  Тюря- простой суп быстро и вкусно
# 4               4                    Фасолевый суп из красной фасоли
# ...           ...                                                ...
# 27879       26468         Салат с филе тунца и огурцами в азиатской…
# 27880       26469          Теплый салат с куриной печенью и яблоками
# 27881       26470                                Самый зеленый салат
# 27882       26471               Теплый салат с тыквой и брынзой под…
# 27883       26472                    Салат из раковых шеек в авокадо
#
#                                              composition  \
# 0      [{'Перловка': 0.1, 'unit': 'стак. (200 мл)'}, ...
# ...

# %%
df.iloc[0]
# Out:
# Unnamed: 0                                                           0
# name                 рассольник классический с перловкой и солеными...
# composition          [{'Перловка': 0.1, 'unit': 'стак. (200 мл)'}, ...
# cooking_type                                               варка,жарка
# Инструкции           Подготовить указанные ингредиенты для приготов...
# dish_type                                                       первое
# Дата                                                        05.06.2015
# photo                                             photo_1000menu_1.jpg
# source               https://1000.menu/cooking/33395-rassolnik-s-pe...
# composition_inter    [{'product_id': 4253, 'name_source': 'Перловая...
# Name: 0, dtype: object

# %%
print(df.iloc[0].Инструкции)
# Out:
# Подготовить указанные ингредиенты для приготовления рассольника с перловой крупой. Мясной бульон сварить заранее из говядины или из курицы, также можно сварить и вегетарианский суп - на воде. Обычно я рассольник варю без томатной пасты, но тут для разнообразия решила добавить - это по желанию. Из специй соль, чёрный перец горошком, душистый перец.
# Перловую крупу промыть до чистой воды.
# В горячий бульон добавить промытую перловку и варить на среднем огне.
# Для рассольника лучше брать кислые, очень солёные огурцы. Если же огурцы обычные, то рекомендуется в рассольник добавлять из сам рассол от огурцов. Солёные огурцы достать из рассола и натереть на крупной тёрке.
# Картофель помыть, обсушить, очистить. Нарезать кубиками. Пока очередь картофеля не подошла, положить его в воду.
# Морковь, лук, чеснок очистить. Морковь натереть на крупной тёрке, лук, сельдерей, чеснок мелко порезать.
# Обжарить в масле овощи, добавив томатной пасты. Томатная паста по желанию.
# ...

# %%
print(df.iloc[0].composition)
# Out:
# [{'Перловка': 0.1, 'unit': 'стак. (200 мл)'}, {'Соленые огурцы': 0.4, 'unit': 'шт.'}, {'Морковь': 0.2, 'unit': 'шт.'}, {'Лук': 0.2, 'unit': 'шт.'}, {'Чеснок': 0.2, 'unit': 'зубч.'}, {'Стебель сельдерея': 1, 'unit': 'шт.'}, {'Картошка': 0.4, 'unit': 'шт.'}, {'Бульон': 0.5, 'unit': 'л'}, {'Томатная паста': 20.0, 'unit': 'гр'}, {'Соль': 'по вкусу', 'unit': 'по вкусу'}, {'Перец': 'по вкусу', 'unit': 'по вкусу'}, {'Зелень': 'по вкусу', 'unit': 'по вкусу'}]
