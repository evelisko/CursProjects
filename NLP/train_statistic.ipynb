# %%
import os
import pandas as pd
import json

# %%
with open('trainer_state.json', 'r') as f:
    file = json.load(f)

# %%
df = pd.DataFrame(file['log_history'])

# %%
df
# Out:
#     epoch  learning_rate    loss  step  eval_loss  eval_runtime  \
# 0    0.12       0.000012  1.7641     2        NaN           NaN
# 1    0.24       0.000024  1.7521     4        NaN           NaN
# 2    0.30            NaN     NaN     5   1.680979      211.6923
# 3    0.36       0.000036  1.6862     6        NaN           NaN
# 4    0.48       0.000048  1.6446     8        NaN           NaN
# 5    0.60       0.000060  1.5978    10        NaN           NaN
# 6    0.60            NaN     NaN    10   1.580341      210.1256
# 7    0.72       0.000072  1.5604    12        NaN           NaN
# 8    0.84       0.000084  1.5348    14        NaN           NaN
# 9    0.90            NaN     NaN    15   1.509741      211.0837
# 10   0.96       0.000096  1.5104    16        NaN           NaN
# 11   1.08       0.000108  1.4828    18        NaN           NaN
# 12   1.20       0.000120  1.4372    20        NaN           NaN
# 13   1.20            NaN     NaN    20   1.434590      211.0447
# ...

# %%
df.loc[(df['eval_loss'].notna())]
# Out:
#     epoch  learning_rate  loss  step  eval_loss  eval_runtime  \
# 2    0.30            NaN   NaN     5   1.680979      211.6923
# 6    0.60            NaN   NaN    10   1.580341      210.1256
# 9    0.90            NaN   NaN    15   1.509741      211.0837
# 13   1.20            NaN   NaN    20   1.434590      211.0447
# 16   1.51            NaN   NaN    25   1.407485      210.4287
# 20   1.81            NaN   NaN    30   1.389620      213.1926
# 23   2.11            NaN   NaN    35   1.370526      212.0164
# 27   2.41            NaN   NaN    40   1.353902      210.6677
# 30   2.71            NaN   NaN    45   1.338537      210.6223
#
#     eval_samples_per_second  eval_steps_per_second
# 2                     7.086                  1.771
# 6                     7.139                  1.785
# 9                     7.106                  1.777
# 13                    7.107                  1.777
# 16                    7.128                  1.782
# ...
